# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn,randint,uniform,sample

# %%
randn(100)
# Out:
# array([ 0.64019341, -0.25834908,  0.38343768, -0.9610126 , -0.38014713,
#        -1.55844621, -0.67156678,  0.54892219, -0.73544593,  0.16443443,
#         1.49746765, -0.65247199,  0.68635978,  0.9057849 , -0.2429901 ,
#         0.01738512, -3.3403671 , -0.23046871,  0.09198574,  0.07183142,
#         0.0130709 ,  0.58551418,  0.85739497, -0.11522169, -1.4437921 ,
#         1.67859185, -0.58727845,  0.39528881, -0.4559717 , -0.27621272,
#         0.64449176,  0.28730149,  1.66216398, -2.41986408, -0.26313245,
#         0.37886789, -0.40959461,  0.93219673,  0.57642215, -0.25226712,
#        -1.23321468, -0.36512127, -0.58095265,  0.05038077, -0.01598829,
#         0.48765073, -0.41249309,  0.27211356, -0.79895883,  1.21666615,
#         0.40607204,  0.82322449,  0.02807711, -0.6139072 , -0.53566945,
#        -0.27274311,  0.64310426,  0.78071968,  0.52974934,  0.64480443,
#         0.66063416,  0.88304468,  1.46370111, -0.0144668 , -0.03330497,
# ...

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2020-06-09', periods=1000),columns=['values'])
df
# Out:
#               values
# 2020-06-09 -0.501352
# 2020-06-10 -0.611694
# 2020-06-11  0.963112
# 2020-06-12  0.834582
# 2020-06-13 -0.234929
# ...              ...
# 2023-03-01  1.195081
# 2023-03-02  0.669478
# 2023-03-03  0.790626
# 2023-03-04  1.112282
# 2023-03-05  1.099250
#
# [1000 rows x 1 columns]

# %%
df.plot(color='Red',alpha=0.8)

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ax=iris.plot(figsize=(10,6),title='Iris Dataset')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
df1=iris.drop(['species'],axis=1)
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df1.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df1.iloc[0].plot(kind='bar')

# %%
df1['sepal_width'].plot.barh()

# %%
df1['sepal_length'].plot(kind='bar',figsize=(20,6))

# %%
df1.plot(kind='hist')

# %%
df1.plot(kind='hist',stacked=True)

# %%
df1.plot(kind='hist',stacked=True,bins=200,orientation='horizontal')

# %%
df1['sepal_length'].diff()
# Out:
# 0      NaN
# 1     -0.2
# 2     -0.2
# 3     -0.1
# 4      0.4
#       ...
# 145    0.0
# 146   -0.4
# 147    0.2
# 148   -0.3
# 149   -0.3
# Name: sepal_length, Length: 150, dtype: float64

# %%
df1['sepal_length'].diff().hist()

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',label='Length')

# %%
ax=df1.plot.scatter(x='sepal_length',y='petal_length',label='Length')
df1.plot.scatter(x='sepal_width',y='petal_width',ax=ax,label='',color='y')

# %%
df1.iloc[0].plot.pie(figsize=(5,5))

# %%
d=df1.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True,figsize=(19,19),fontsize=14,autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000010D286BC688>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df1,figsize=(8,8),color='r',diagonal='hist',grid=True,alpha=0.6)
plt.show()

# %%
scatter_matrix(df1,figsize=(8,8),color='r',diagonal='kde',grid=True,alpha=0.6)
plt.show()

# %% [markdown]
# ts=sns.load_dataset('ts') #Time series data set (forgot name of dataset)
# ts
